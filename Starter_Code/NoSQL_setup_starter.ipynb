# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# Import the data provided in the `establishments.json` file from your Terminal. Name the database `uk_food` and the collection `establishments`.
#
# Within this markdown cell, copy the line of text you used to import the data from your Terminal. This way, future analysts will be able to repeat your process.
#
# e.g.: Import the dataset with        mongoimport --type json -d uk_food -c establishments --jsonArray --drop Resources/establishments.json

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
# Importing .json file from Jupyter notebook. #Importing establishments.json file  in a collection called 'establishments' which is in 'uk_food' database. 
# !mongoimport --type json -d uk_food -c establishments --jsonArray --drop Resources/establishments.json
# Out:
# 2025-01-30T01:24:44.652-0500	connected to: mongodb://localhost/
# 2025-01-30T01:24:44.661-0500	dropping: uk_food.establishments
# 2025-01-30T01:24:47.657-0500	[#####...................] uk_food.establishments	8.89MB/39.3MB (22.6%)
# 2025-01-30T01:24:50.654-0500	[############............] uk_food.establishments	19.8MB/39.3MB (50.4%)
# 2025-01-30T01:24:53.653-0500	[##################......] uk_food.establishments	30.8MB/39.3MB (78.3%)
# 2025-01-30T01:24:56.133-0500	[########################] uk_food.establishments	39.3MB/39.3MB (100.0%)
# 2025-01-30T01:24:56.134-0500	39779 document(s) imported successfully. 0 document(s) failed to import.

# %%
# Create an instance of MongoClient
# MongoClient is a class from the pymongo library that allows Python to interact with a MongoDB database.
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
pprint(mongo.list_database_names())
# Out:
# ['admin',
#  'autosaurus',
#  'classDB',
#  'config',
#  'epa',
#  'fruits_db',
#  'local',
#  'met',
#  'petsitly_marketing',
#  'uk_food']

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our new database
pprint(db.list_collection_names())
# Out:
# ['establishments']

# %%
# review a document in the establishments collection
#.find_one() retrieves the first document found in the collection.
pprint(db.establishments.find_one())
# Out:
# {'AddressLine1': 'The Bay',
#  'AddressLine2': 'St Margarets Bay',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Refreshment Kiosk',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4587.347174863443,
#  'FHRSID': 254719,
#  'LocalAuthorityBusinessID': 'PI/000069980',
#  'LocalAuthorityCode': '182',
#  'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#  'LocalAuthorityName': 'Dover',
#  'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT15 6DY',
#  'RatingDate': '2022-03-24T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('679b9743dc6038ef9deb7aa6'),
#  'geocode': {'latitude': '51.152225', 'longitude': '1.387974'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/254719',
#             'rel': 'self'}],
# ...

# %%
# assign the 'establishments' collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 2: Update the Database

# %% [markdown]
# 1. An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following restaurant "Penang Flavours" to the database.

# %%
# Create a dictionary for the new restaurant data
post = {
    "BusinessName":"Penang Flavours",
    "BusinessType":"Restaurant/Cafe/Canteen",
    "BusinessTypeID":"",
    "AddressLine1":"Penang Flavours",
    "AddressLine2":"146A Plumstead Rd",
    "AddressLine3":"London",
    "AddressLine4":"",
    "PostCode":"SE18 7DY",
    "Phone":"",
    "LocalAuthorityCode":"511",
    "LocalAuthorityName":"Greenwich",
    "LocalAuthorityWebSite":"http://www.royalgreenwich.gov.uk",
    "LocalAuthorityEmailAddress":"health@royalgreenwich.gov.uk",
    "scores":{
        "Hygiene":"",
        "Structural":"",
        "ConfidenceInManagement":""
    },
    "SchemeType":"FHRS",
    "geocode":{
        "longitude":"0.08384000",
        "latitude":"51.49014200"
    },
    "RightToReply":"",
    "Distance":4623.9723280747176,
    "NewRatingPending":True
}

# %%
# Insert the new restaurant (Penang Flavours) information into the collection
# Adds a single document (post) into the establishments collection.
establishments.insert_one(post)
# Out:
# InsertOneResult(ObjectId('679ba2c22028dea6266ae5fb'), acknowledged=True)

# %%
# Check that the new restaurant was inserted
# The query dictionary specifies that the search should match documents where the "BusinessName" field 
# is "Penang Flavours".
query = {'BusinessName':"Penang Flavours"}
establishments.find_one(query)
# Out:
# {'_id': ObjectId('679ba2c22028dea6266ae5fb'),
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'PostCode': 'SE18 7DY',
#  'Phone': '',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'scores': {'Hygiene': '', 'Structural': '', 'ConfidenceInManagement': ''},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '0.08384000', 'latitude': '51.49014200'},
#  'RightToReply': '',
#  'Distance': 4623.972328074718,
#  'NewRatingPending': True}

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields
# The query filters documents where the "BusinessType" field is equal to "Restaurant/Cafe/Canteen".
query = {'BusinessType':'Restaurant/Cafe/Canteen'}

# This dictionary specifies which fields should be included in the result.
# 1 means that we want to include these fields. Therefore,BusinessTypeID and BusinessType are included
fields = {'BusinessTypeID':1 ,'BusinessType':1 }

# searches the establishments collection for all documents that match the query filter
results = establishments.find(query, fields)

# This loops through each document returned by the query.
for result in results:
    pprint(result)
# Out:
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('679b9743dc6038ef9deb7aa6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('679b9743dc6038ef9deb7aa7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('679b9743dc6038ef9deb7aa8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('679b9743dc6038ef9deb7aa9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('679b9743dc6038ef9deb7aaa')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('679b9743dc6038ef9deb7ab1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('679b9743dc6038ef9deb7ab4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('679b9743dc6038ef9deb7ab5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
# ...

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID
# Penang Flavours do not have a BusinessTypeID.Therefore, it is updated to 1 since its BusinessType is Restaurant/Cafe/Canteen
# which has a BusinessTypeID =1
#  Uses $set to update the  field. 
# There is only one document for Penang Flavours in the collection. So we use .update_one().
establishments.update_one({'BusinessName': "Penang Flavours"}, {'$set': {'BusinessTypeID' : 1}})
# Out:
# UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
# Confirm that the new restaurant was updated
# searching for documents where the BusinessName field is "Penang Flavours"
query = {'BusinessName':"Penang Flavours"}

# find() method is used to search for the documents specified in the query 
results = establishments.find(query)

# This loops through each document returned by the query.
for result in results:
# prints each MongoDB document in a well-formatted way, making it easier to read.
    pprint(result)
# Out:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('679ba2c22028dea6266ae5fb'),
#  'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"
query = {'LocalAuthorityName': "Dover"}

# .count_documents() searches the establishments collection and counts how many documents match the given query.
establishments.count_documents(query)
# Out:
# 994

# %%
# Delete all documents where LocalAuthorityName is "Dover"
# delete_many() removes all documents matching the query from the establishments collection.
establishments.delete_many(query)
# Out:
# DeleteResult({'n': 994, 'ok': 1.0}, acknowledged=True)

# %%
# Check if any remaining documents include Dover
# counts if any documents with name 'Dover' still exixt in the collection.
print(establishments.count_documents(query))

# checks by finding a document with local authority name 'Dover'
pprint(establishments.find_one(query))
# Out:
# 0
# None

# %%
# Check that other documents remain with 'find_one'
establishments.find_one()
# Out:
# {'_id': ObjectId('679b9743dc6038ef9deb7d8d'),
#  'FHRSID': 647177,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000041489',
#  'BusinessName': 'Wear Bay Bowls Club',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'AddressLine1': 'Wear Bay Road',
#  'AddressLine2': 'Folkestone',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'PostCode': 'CT19 6PY',
#  'Phone': '',
#  'RatingValue': '4',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingDate': '2014-03-31T00:00:00',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 10},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '1.196408', 'latitude': '51.086058'},
#  'RightToReply': '',
#  'Distance': 4591.821311183521,
#  'NewRatingPending': False,
# ...

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers.

# %% [markdown]
# Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for longitude and latitude
# This query updates multiple documents in the establishments collection by converting the 
# geocode.latitude field from string to double.
establishments.update_many({},[{'$set':{'geocode.latitude':{'$toDouble': '$geocode.latitude'}}}])

# This query updates multiple documents in the establishments collection by converting the 
# geocode.longitude field from string to double.
establishments.update_many({},[{'$set':{'geocode.longitude': {'$toDouble':'$geocode.longitude'}}}])
# Out:
# UpdateResult({'n': 38786, 'nModified': 38786, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %% [markdown]
# Use `update_many` to convert `RatingValue` to integer numbers.

# %%
# Set non 1-5 Rating Values to Null
non_ratings = ["AwaitingInspection", "Awaiting Inspection", "AwaitingPublication", "Pass", "Exempt"]
establishments.update_many({"RatingValue": {"$in": non_ratings}}, [ {'$set':{ "RatingValue" : None}} ])
# Out:
# UpdateResult({'n': 4091, 'nModified': 4091, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
# Change the data type from String to Integer for RatingValue
# This query updates multiple documents in the establishments collection by converting the 
# RatingValue field from string to integer.
establishments.update_many({},[{'$set':{'RatingValue': {'$toInt':'$RatingValue'}}}])
# Out:
# UpdateResult({'n': 38786, 'nModified': 34695, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
# Check that the coordinates and rating value are now numbers

result = establishments.find_one({}, {"geocode.latitude": 1, "geocode.longitude": 1, "RatingValue" : 1 })
pprint(result)
 
# The value of RatingValue , ie, 4 has changed from string to integer(4 is no longer in quotes ). 
# The same is applicable to latitude and longitude.It is converted to float.
# Out:
# {'RatingValue': 4,
#  '_id': ObjectId('679b9743dc6038ef9deb7d8d'),
#  'geocode': {'latitude': 51.086058, 'longitude': 1.196408}}
